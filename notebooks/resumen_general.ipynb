# %%
# !pip install google-cloud-bigquery pandas

# %%
# !pip show db-dtypes

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/Marco_De_Castilla_V/Downloads/numeric-advice-452700-j9-84eafacb55e7.json"

# %%
from google.cloud import bigquery
import pandas as pd

# Crea el cliente de BigQuery
client = bigquery.Client()

# %%
import google.cloud.bigquery
print(google.cloud.bigquery.__version__)

# %%
import google.cloud.bigquery
print(google.cloud.bigquery.__version__)

# %%
import sys
print(sys.executable)

# %%
from pandas import read_gbq

query_resumen = """
SELECT *
FROM `numeric-advice-452700-j9.neo_bank_.resumen_general`
"""

df_resumen = read_gbq(query_resumen, project_id="numeric-advice-452700-j9")
df_resumen.head()

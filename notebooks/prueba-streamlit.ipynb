# %%
import pandas as pd

# Carga tu DataFrame grande
df = pd.read_csv("../data/df_n.csv", parse_dates=["create_date_user", "create_date_transaction"])

df = df.drop(columns=["Unnamed: 0"])

# Toma una muestra aleatoria de 5000 registros
df_sample = df.sample(n=5000, random_state=42)

# Guarda el nuevo CSV para usarlo en tu dashboard
df_sample.to_csv("../data/df_sample.csv", index=False)

df_sample
